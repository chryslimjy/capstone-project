# %%
import matplotlib.pyplot as plt

# Data
data = [
    [18, 15, 13, 17, 12, 16, 19, 15, 16, 18, 19, 16, 14, 14, 23],
    [17, 16, 20, 18, 17, 25, 30, 12, 18, 14, 16, 16, 15, 19, 23],
    [19, 20, 23, 16, 17, 14, 12, 14, 15, 13, 16, 18, 14, 16, 16],
    [50, 14, 16, 20, 23, 17, 16, 13, 15, 19, 18, 13, 15, 17, 16]
]

# Create the horizontal boxplot
plt.boxplot(data, vert=False, labels=['SearchQuery', 'BrowserCommand', 'OpenSearchResult', 'Unknown'])

# Add title and labels
plt.title('Average Intent Prediction Time')
plt.ylabel('Intent')
plt.xlabel('Detection Time (ms)')

# Show the plot
plt.show()
# Out:
# C:\Users\Chrystal Lim\AppData\Local\Temp\ipykernel_12360\1678966064.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, vert=False, labels=['SearchQuery', 'BrowserCommand', 'OpenSearchResult', 'Unknown'])
